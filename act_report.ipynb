# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# # WeRateDogs Twitter Data Analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# * WeRateDogs is a popular Twitter account where they rate dogs and post more information about them.

# %% [markdown]
# ## Key Insights

# %% [markdown]
# ### Insight 1: The probability of the model recognizing what is in the images relative to the number of images.
# * I found that the more images in a tweet, the more accurate the model was in recognizing what was in the images.

# %% [markdown]
# ### Insight 2: The number of likes relative to the number of photos in the tweet.
# * I found that the more photos there are, the less the number of likes on the tweet, and this indicates the user’s need to focus on one photo.

# %% [markdown]
# ### Insight 3: The user liked the tweet in relation to the probability of recognizing a sample image of a dog.
# * As the probability of the model recognizing images as a dog increases, users will like the tweet more.

# %% [markdown]
# ### Insight 4: Dog Ratings Distribution.
# * The majority of dog ratings are above 10, with 12/10 being the most common rating. This unique rating system is an essential part of the magic of the account, and demonstrates the intensity of their admiration for dogs.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# * My analysis of the WeRateDogs Twitter archive provided valuable insights into dog ratings, user interests for rating and liking, rating trends, and popular dog breeds. This data, results, and analysis highlight the unique appeal of the account and its widespread popularity.
# * I hope that my analysis has been useful to you and that you have learned the importance of this account for extracting data
